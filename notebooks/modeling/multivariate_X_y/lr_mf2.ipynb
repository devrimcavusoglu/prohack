# %%
# Scientific libraries		              
import numpy as np		              
import scipy as sp		              
import pandas as pd		              
import json		              
import missingno as msno		              

# Loading Plotting Modules		              
import matplotlib		              
import matplotlib.pyplot as plt		              
import seaborn as sns		              
# %matplotlib inline		              
import chart_studio.plotly as py		              
import plotly.figure_factory as ff		              
import plotly.graph_objects as go		              
import plotly.express as px		              
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot		              
init_notebook_mode(connected=True)		              
		              
import os		              
import gc
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Setting Data Frame Options                      
pd.set_option('display.max_rows', 40)                      
pd.set_option('display.max_columns', 50)                      
pd.set_option('display.width', 100)                      
pd.set_option('display.max_colwidth', 100)                      

# Setting Plot Configuration                      
sns.set(rc={'figure.figsize':(19,11)}, style = 'white')

# %%
train = pd.read_csv('../../eda/outputs/imputed_c4_scaled_train.csv')                
m, n = train.shape                
print('Data Frame: {} x {}'.format(m,n))                
train.head()
# Out:
# Data Frame: 3865 x 79
#    existence expectancy index  existence expectancy at birth  Gross income per capita  \
# 0                    0.391903                       0.436379                 0.180134
# 1                    0.577139                       0.706534                 0.200356
# 2                    0.422009                       0.382670                 0.056671
# 3                    0.320718                       0.273319                 0.133938
# 4                    0.746424                       0.718583                 0.536780
#
#    Income Index  Expected years of education (galactic years)  \
# 0      0.330914                                      0.191779
# 1      0.523652                                      0.296773
# 2      0.194190                                      0.217680
# 3      0.297991                                      0.202692
# 4      0.784350                                      0.431892
#
#    Mean years of education (galactic years)  Intergalactic Development Index (IDI)  \
# 0                                  0.357754                               0.344793
# 1                                  0.164296                               0.583800
# 2                                  0.213422                               0.203753
# 3                                  0.338361                               0.217090
# 4                                  0.657389                               0.663786
#
#    Education Index  Intergalactic Development Index (IDI), Rank  \
# 0         0.337492                                     0.593450
# 1         0.257466                                     0.538425
# 2         0.161114                                     0.747860
# 3         0.322132                                     0.620007
# 4         0.674673                                     0.243647
#
#    Population using at least basic drinking-water services (%)  \
# 0                                                     0.355888
# 1                                                     0.614669
# 2                                                     0.279038
# 3                                                     0.321512
# 4                                                     0.806120
#
#    Population using at least basic sanitation services (%)  Gross capital formation (% of GGP)  \
# 0                                                 0.277196                            0.474812
# 1                                                 0.594579                            0.447638
# 2                                                 0.237096                            0.206892
# 3                                                 0.250549                            0.373955
# 4                                                 0.780922                            0.424333
#
#    Population, total (millions)  Population, urban (%)  \
# 0                      0.100170               0.029288
# 1                      0.069502               0.608693
# 2                      0.053043               0.334331
# 3                      0.057994               0.250602
# 4                      0.094456               0.731785
#
#    Mortality rate, under-five (per 1,000 live births)  \
# 0                                            0.393048
# 1                                            0.305141
# 2                                            0.595041
# 3                                            0.734030
# 4                                            0.070185
#
#    Mortality rate, infant (per 1,000 live births)  \
# 0                                        0.613240
# 1                                        0.278800
# 2                                        0.636431
# 3                                        0.924904
# 4                                        0.226070
#
#    Old age dependency ratio (old age (65 and older) per 100 creatures (ages 15-64))  \
# 0                                                                          0.169169
# 1                                                                          0.182756
# 2                                                                          0.243444
# 3                                                                          0.180379
# 4                                                                          0.442926
#
#    Population, ages 15–64 (millions)  Population, ages 65 and older (millions)  \
# 0                           0.103254                                  0.124460
# 1                           0.115696                                  0.122159
# 2                           0.114713                                  0.099141
# 3                           0.152305                                  0.111382
# 4                           0.120113                                  0.118572
#
#    Life expectancy at birth, male (galactic years)  \
# 0                                         0.316953
# 1                                         0.544774
# 2                                         0.360129
# 3                                         0.201810
# 4                                         0.813409
#
#    Life expectancy at birth, female (galactic years)  Population, under age 5 (millions)  \
# 0                                           0.462997                            0.074950
# 1                                           0.574020                            0.067586
# 2                                           0.291935                            0.131685
# 3                                           0.224279                            0.133741
# 4                                           0.701534                            0.107015
#
#    Young age (0-14) dependency ratio (per 100 creatures ages 15-64)  \
# 0                                                          0.671548
# 1                                                          0.594823
# 2                                                          0.795227
# 3                                                          0.667121
# 4                                                          0.327374
#
#    Adolescent birth rate (births per 1,000 female creatures ages 15-19)  \
# 0                                                              0.581831
# 1                                                              0.346862
# 2                                                              0.784964
# 3                                                              0.670240
# 4                                                              0.169402
#
#    Total unemployment rate (female to male ratio)  ...  \
# 0                                        0.055885  ...
# 1                                        0.063764  ...
# 2                                        0.049980  ...
# 3                                        0.053614  ...
# 4                                        0.060880  ...
#
#    Estimated gross galactic income per capita, female  \
# 0                                            0.157990
# 1                                            0.195096
# 2                                            0.147063
# 3                                            0.131608
# 4                                            0.654762
#
#    Rural population with access to electricity (%)  \
# 0                                         0.234921
# 1                                         0.622902
# 2                                         0.213918
# 3                                         0.229581
# 4                                         0.769611
#
#    Domestic credit provided by financial sector (% of GGP)  \
# 0                                                 0.191719
# 1                                                 0.160763
# 2                                                 0.192623
# 3                                                 0.198887
# 4                                                 0.335516
#
#    Population with at least some secondary education, female (% ages 25 and older)  \
# 0                                                                         0.223137
# 1                                                                         0.339497
# 2                                                                         0.237297
# 3                                                                         0.216708
# 4                                                                         0.475970
#
#    Population with at least some secondary education, male (% ages 25 and older)  \
# 0                                                                       0.283052
# 1                                                                       0.317052
# 2                                                                       0.301120
# 3                                                                       0.301552
# 4                                                                       0.453048
#
#    Gross fixed capital formation (% of GGP)  Remittances, inflows (% of GGP)  \
# 0                                  0.515809                         0.053530
# 1                                  0.336151                         0.036478
# 2                                  0.178143                         0.024396
# 3                                  0.324499                         0.056827
# 4                                  0.357215                         0.058588
#
#    Population with at least some secondary education (% ages 25 and older)  \
# 0                                                                 0.238422
# 1                                                                 0.250016
# 2                                                                 0.101404
# 3                                                                 0.240170
# 4                                                                 0.406833
#
#    Intergalactic inbound tourists (thousands)  \
# 0                                    0.091255
# 1                                    0.092411
# 2                                    0.084511
# 3                                    0.087511
# 4                                    0.087624
#
#    Gross enrolment ratio, primary (% of primary under-age population)  \
# 0                                                            0.374999
# 1                                                            0.596507
# 2                                                            0.426323
# 3                                                            0.334398
# 4                                                            0.555963
#
#    Respiratory disease incidence (per 100,000 people)  \
# 0                                            0.324717
# 1                                            0.229269
# 2                                            0.298794
# 3                                            0.328659
# 4                                            0.131623
#
#    Interstellar phone subscriptions (per 100 people)  \
# 0                                           0.205774
# 1                                           0.232885
# 2                                           0.141450
# 3                                           0.130522
# 4                                           0.594284
#
#    Interstellar Data Net users, total (% of population)  Current health expenditure (% of GGP)  \
# 0                                              0.203008                               0.219118
# 1                                              0.230264                               0.226282
# 2                                              0.191675                               0.255438
# 3                                              0.190795                               0.567732
# 4                                              0.574955                               0.369993
#
#    Intergalactic Development Index (IDI), female  Intergalactic Development Index (IDI), male  \
# 0                                       0.323646                                     0.293293
# 1                                       0.513055                                     0.517547
# 2                                       0.264287                                     0.191852
# 3                                       0.239026                                     0.211705
# 4                                       0.760254                                     0.750144
#
#    Gender Development Index (GDI)  Intergalactic Development Index (IDI), female, Rank  \
# 0                        0.684113                                             0.599405
# 1                        0.686377                                             0.610330
# 2                        0.641791                                             0.802950
# 3                        0.643656                                             0.580420
# 4                        0.853754                                             0.263455
#
#    Intergalactic Development Index (IDI), male, Rank  Adjusted net savings   \
# 0                                           0.578120               0.682786
# 1                                           0.543835               0.686677
# 2                                           0.803173               0.700804
# 3                                           0.586058               0.668301
# 4                                           0.253005               0.802429
#
#    Creature Immunodeficiency Disease prevalence, adult (% ages 15-49), total  \
# 0                                                                   0.196825
# 1                                                                   0.146853
# 2                                                                   0.204769
# 3                                                                   0.188288
# 4                                                                   0.180325
#
#    Private galaxy capital flows (% of GGP)  Gender Inequality Index (GII)    galaxy         y
# 0                                 0.917897                       0.766789  0.047759  0.052590
# 1                                 0.911980                       0.654790  0.057951  0.059868
# 2                                 0.916773                       0.796380  0.042337  0.050449
# 3                                 0.917065                       0.782493  0.041047  0.049394
# 4                                 0.916510                       0.318590  0.208920  0.154247
#
# [5 rows x 79 columns]

# %%
test = pd.read_csv('../../eda/outputs/imputed_c4_scaled_test.csv')
m, n = test.shape                
print('Data Frame: {} x {}'.format(m,n))                
test.head()
# Out:
# Data Frame: 890 x 78
#    existence expectancy index  existence expectancy at birth  Gross income per capita  \
# 0                    0.223149                       0.261673                 0.081769
# 1                    0.295267                       0.347279                 0.023537
# 2                    0.325719                       0.379784                 0.183134
# 3                    0.330545                       0.388440                 0.135444
# 4                    0.352414                       0.320083                 0.159303
#
#    Income Index  Expected years of education (galactic years)  \
# 0      0.281643                                      0.285646
# 1      0.358363                                      0.148548
# 2      0.282857                                      0.344409
# 3      0.510055                                      0.337444
# 4      0.213648                                      0.284707
#
#    Mean years of education (galactic years)  Intergalactic Development Index (IDI)  \
# 0                                  0.512036                               0.285081
# 1                                  0.197493                               0.233549
# 2                                  0.234078                               0.282610
# 3                                  0.475187                               0.435767
# 4                                  0.259580                               0.267943
#
#    Education Index  Intergalactic Development Index (IDI), Rank  \
# 0         0.339331                                     0.831239
# 1         0.203839                                     0.885923
# 2         0.274409                                     0.894031
# 3         0.308930                                     0.754044
# 4         0.361698                                     0.838913
#
#    Population using at least basic drinking-water services (%)  \
# 0                                                     0.698324
# 1                                                     0.218971
# 2                                                     0.248289
# 3                                                     0.358968
# 4                                                     0.355017
#
#    Population using at least basic sanitation services (%)  Gross capital formation (% of GGP)  \
# 0                                                 0.355976                            0.197936
# 1                                                 0.236344                            0.404853
# 2                                                 0.254133                            0.386102
# 3                                                 0.336148                            0.423028
# 4                                                 0.270191                            0.174589
#
#    Population, total (millions)  Population, urban (%)  \
# 0                      0.103516               0.470690
# 1                      0.097937               0.291136
# 2                      0.099930               0.287194
# 3                      0.102746               0.415630
# 4                      0.150680               0.393780
#
#    Mortality rate, under-five (per 1,000 live births)  \
# 0                                            0.382672
# 1                                            0.434841
# 2                                            0.404629
# 3                                            0.362385
# 4                                            0.576674
#
#    Mortality rate, infant (per 1,000 live births)  \
# 0                                        0.466538
# 1                                        0.506936
# 2                                        0.468073
# 3                                        0.397285
# 4                                        0.613892
#
#    Old age dependency ratio (old age (65 and older) per 100 creatures (ages 15-64))  \
# 0                                                                          0.172478
# 1                                                                          0.185795
# 2                                                                          0.184625
# 3                                                                          0.162909
# 4                                                                          0.202759
#
#    Population, ages 15–64 (millions)  Population, ages 65 and older (millions)  \
# 0                           0.103171                                  0.114102
# 1                           0.107588                                  0.116823
# 2                           0.108145                                  0.116891
# 3                           0.099087                                  0.112577
# 4                           0.100490                                  0.066797
#
#    Life expectancy at birth, male (galactic years)  \
# 0                                         0.303145
# 1                                         0.313677
# 2                                         0.380257
# 3                                         0.383687
# 4                                         0.354488
#
#    Life expectancy at birth, female (galactic years)  Population, under age 5 (millions)  \
# 0                                           0.315039                            0.121412
# 1                                           0.317044                            0.109599
# 2                                           0.325315                            0.113637
# 3                                           0.347517                            0.115578
# 4                                           0.369471                            0.118236
#
#    Young age (0-14) dependency ratio (per 100 creatures ages 15-64)  \
# 0                                                          0.735960
# 1                                                          0.786487
# 2                                                          0.789005
# 3                                                          0.724501
# 4                                                          0.771346
#
#    Adolescent birth rate (births per 1,000 female creatures ages 15-19)  \
# 0                                                              0.564175
# 1                                                              0.614688
# 2                                                              0.597515
# 3                                                              0.512371
# 4                                                              0.537664
#
#    Total unemployment rate (female to male ratio)  ...  \
# 0                                        0.056596  ...
# 1                                        0.054512  ...
# 2                                        0.054085  ...
# 3                                        0.060768  ...
# 4                                        0.053521  ...
#
#    Estimated gross galactic income per capita, male  \
# 0                                          0.103798
# 1                                          0.103189
# 2                                          0.111775
# 3                                          0.120195
# 4                                          0.093024
#
#    Estimated gross galactic income per capita, female  \
# 0                                            0.165773
# 1                                            0.159326
# 2                                            0.168655
# 3                                            0.203256
# 4                                            0.215890
#
#    Rural population with access to electricity (%)  \
# 0                                         0.371389
# 1                                         0.224915
# 2                                         0.220301
# 3                                         0.314744
# 4                                         0.280913
#
#    Domestic credit provided by financial sector (% of GGP)  \
# 0                                                 0.226804
# 1                                                 0.202339
# 2                                                 0.203169
# 3                                                 0.202032
# 4                                                 0.209716
#
#    Population with at least some secondary education, female (% ages 25 and older)  \
# 0                                                                         0.357202
# 1                                                                         0.192795
# 2                                                                         0.204484
# 3                                                                         0.335615
# 4                                                                         0.145851
#
#    Population with at least some secondary education, male (% ages 25 and older)  \
# 0                                                                       0.414912
# 1                                                                       0.197576
# 2                                                                       0.252744
# 3                                                                       0.357082
# 4                                                                       0.333797
#
#    Gross fixed capital formation (% of GGP)  Remittances, inflows (% of GGP)  \
# 0                                  0.148443                         0.064476
# 1                                  0.334606                         0.054913
# 2                                  0.333695                         0.055835
# 3                                  0.368215                         0.052951
# 4                                  0.101534                         0.062461
#
#    Population with at least some secondary education (% ages 25 and older)  \
# 0                                                                 0.373681
# 1                                                                 0.201713
# 2                                                                 0.237795
# 3                                                                 0.337196
# 4                                                                 0.237129
#
#    Intergalactic inbound tourists (thousands)  \
# 0                                    0.090410
# 1                                    0.089152
# 2                                    0.087506
# 3                                    0.089707
# 4                                    0.089961
#
#    Gross enrolment ratio, primary (% of primary under-age population)  \
# 0                                                            0.479448
# 1                                                            0.306161
# 2                                                            0.545510
# 3                                                            0.555967
# 4                                                            0.394433
#
#    Respiratory disease incidence (per 100,000 people)  \
# 0                                            0.281987
# 1                                            0.248583
# 2                                            0.237936
# 3                                            0.305587
# 4                                            0.325619
#
#    Interstellar phone subscriptions (per 100 people)  \
# 0                                           0.273287
# 1                                           0.179999
# 2                                           0.203944
# 3                                           0.270666
# 4                                           0.241243
#
#    Interstellar Data Net users, total (% of population)  Current health expenditure (% of GGP)  \
# 0                                              0.222402                               0.260025
# 1                                              0.205893                               0.244112
# 2                                              0.210110                               0.259607
# 3                                              0.222756                               0.239138
# 4                                              0.275256                               0.237723
#
#    Intergalactic Development Index (IDI), female  Intergalactic Development Index (IDI), male  \
# 0                                       0.377036                                     0.341749
# 1                                       0.270051                                     0.238774
# 2                                       0.339556                                     0.269320
# 3                                       0.463486                                     0.354120
# 4                                       0.381321                                     0.283148
#
#    Gender Development Index (GDI)  Intergalactic Development Index (IDI), female, Rank  \
# 0                        0.717844                                             0.797097
# 1                        0.653919                                             0.810743
# 2                        0.719630                                             0.794933
# 3                        0.752725                                             0.766830
# 4                        0.622986                                             0.879547
#
#    Intergalactic Development Index (IDI), male, Rank  Adjusted net savings   \
# 0                                           0.786682               0.636931
# 1                                           0.826771               0.678842
# 2                                           0.800842               0.666669
# 3                                           0.753798               0.700512
# 4                                           0.939963               0.611172
#
#    Creature Immunodeficiency Disease prevalence, adult (% ages 15-49), total  \
# 0                                                                   0.233326
# 1                                                                   0.206223
# 2                                                                   0.218372
# 3                                                                   0.232684
# 4                                                                   0.235344
#
#    Private galaxy capital flows (% of GGP)  Gender Inequality Index (GII)    galaxy
# 0                                 0.913618                       0.738867  0.045937
# 1                                 0.914100                       0.783630  0.042850
# 2                                 0.915718                       0.736398  0.042850
# 3                                 0.916179                       0.709852  0.042614
# 4                                 0.915736                       0.794609  0.042337
#
# [5 rows x 78 columns]

# %%
from lightgbm import LGBMRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
def plot_lgb_history(history):
    for i, key in enumerate(history.evals_result_):
        if i == 0:
            res = pd.DataFrame(history.evals_result_[key])
            res['index'] = np.arange(len(history.evals_result_[key]['l2']))
            res['type'] = key
        temp = pd.DataFrame(history.evals_result_[key])
        temp['type'] = key
        temp['index'] = np.arange(len(history.evals_result_[key]['l2']))
        
        res = res.append(temp, ignore_index=True)
        del temp; gc.collect()
    
    fig = px.scatter(data_frame=res, x='index', y='l2', color='type',
                 title='Learning curve')
    fig.show()

# %%
try:
    drop_cols = ['galactic year']
    train.drop(drop_cols, axis=1, inplace=True)
    test.drop(drop_cols, axis=1, inplace=True)
except:
    pass

# %%
y = 'y'
X = train.columns.drop(y)

# %%
X_train, X_val, y_train, y_val = train_test_split(train[X].to_numpy(), train[y].to_numpy(),
                                                  test_size=0.25, random_state=42)
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((2898, 78), (967, 78), (2898,), (967,))

# %%
eval_set = [(X_train, y_train), (X_val, y_val)]

# %%
from sklearn.linear_model import Lasso, LinearRegression

# %%
# num_leaves << 2^(max_depth)

en = LinearRegression()

history = en.fit(X=X_train, y=y_train)

y_pred_train = en.predict(X_train)
y_pred_val = en.predict(X_val)

train_rmse = mean_squared_error(y_true=y_train, y_pred=y_pred_train, squared=False)
val_rmse = mean_squared_error(y_true=y_val, y_pred=y_pred_val, squared=False)
print(f'RMSE Train: {train_rmse: .8f}')
print(f'RMSE Valid: {val_rmse: .8f}\tRatio (val/train): {val_rmse/train_rmse: .5f}')

# plot_lgb_history(lgbm)
# Out:
# RMSE Train:  0.01388216
# RMSE Valid:  0.01581828	Ratio (val/train):  1.13947

# %%
train[X].shape, train[y].shape
# Out:
# ((3865, 78), (3865,))

# %%
# num_leaves << 2^(max_depth)

en = LinearRegression()


X_train, y_train = train[X].to_numpy(), train[y].to_numpy()

history = en.fit(X=X_train, y=y_train)

y_pred_train = en.predict(train[X])

train_rmse = mean_squared_error(y_true=train[y], y_pred=y_pred_train, squared=False)
print(f'RMSE Train: {train_rmse: .8f}')

# plot_lgb_history(history)
# Out:
# RMSE Train:  0.01430185

# %%
X_test = test[X].to_numpy()

# %%
X_train.shape, X_test.shape
# Out:
# ((3865, 78), (890, 78))

# %%
y_pred_test = en.predict(X_test)

# %%
pred_output = pd.DataFrame()
pred_output['y_pred'] = y_pred_test
pred_output.reset_index(inplace=True)
pred_output.rename(columns = {
    "index": "Index"
    }, inplace=True)
pred_output
# Out:
#      Index    y_pred
# 0        0  0.045999
# 1        1  0.042756
# 2        2  0.039889
# 3        3  0.038300
# 4        4  0.042179
# ..     ...       ...
# 885    885  0.044775
# 886    886  0.052618
# 887    887  0.072523
# 888    888  0.064594
# 889    889  0.045739
#
# [890 rows x 2 columns]

# %%
import datetime
os.makedirs('../outputs', exist_ok=True)
ts_now = datetime.datetime.now().strftime('%Y%m%d_%H%M%S')
pred_output.to_csv(f'../outputs/y_pred_lr_c3_{ts_now}.csv', index=False)

# %%
print("Train samples:", y_pred_train.shape[0])
print("Validation samples:", y_pred_val.shape[0])
print("Test samples:", y_pred_test.shape[0])
# Out:
# Train samples: 3865
# Validation samples: 967
# Test samples: 890

# %%
px.histogram(pd.DataFrame(y_pred_train), x=0)
# Out:
# <div>
#
#
#             <div id="0da04386-b819-477b-82ce-bce472b97485" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0da04386-b819-477b-82ce-bce472b97485")) {
#                     Plotly.newPlot(
#                         '0da04386-b819-477b-82ce-bce472b97485',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "0=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [0.046637279384446485, 0.0480293217922874, 0.062213925127560805, 0.05649953027308743, 0.21220063608570472, 0.043735783123964506, 0.04366583957883535, 0.05903296389575211, 0.03654052070743984, 0.048817391769526104, 0.058779922893204654, 0.05022661777203512, 0.21111667983177196, 0.17576556079233596, 0.04068201370243171, 0.08246022350090258, 0.07406092213781579, 0.06369720201204992, 0.07124430104412645, 0.06185100835170245, 0.043143860524934546, 0.06526465338342383, 0.21927406346655365, 0.0751403612726946, 0.047675949311873494, 0.0489172468087017, 0.07217067254468959, 0.04826064709787392, 0.07740615624549209, 0.1590041375263777, 0.06914297388437166, 0.04889512714425397, 0.03175261474267338, 0.05880914794277485, 0.06521736800877684, 0.06609610707638999, 0.03557462013687492, 0.0627301395478703, 0.0633079113594105, 0.08672891270318364, 0.1522434204250792, 0.06908435320810911, 0.041678495738084506, 0.05892644727540214, 0.10808606183191846, 0.15429722070875174, 0.08934414653048074, 0.1310432954757678, 0.04977072899474867, 0.04411852229527034, 0.048199398257333714, 0.09365321731476677, 0.18034977519643464, 0.050313815224773246, 0.07269600587612672, 0.07969166745990261, 0.055233470135102145, 0.06776898705917152, 0.053155478108476754, 0.06256382445616941, 0.19485640905974433, 0.17363698717125337, 0.05985781103852003, 0.3072379602625073, 0.10906661536297717, 0.042193151360814515, 0.07530662539841049, 0.04615967059591991, 0.05222188286303052, 0.07681121389830022, 0.07865865024271851, 0.06636598410739013, 0.05310510221870245, 0.1585130744278565, 0.04818857751641655, 0.05281669424958562, 0.04186683101143161, 0.06657432011342412, 0.04166596335803904, 0.052352382510054765, 0.0829825259331416, 0.06355008197848178, 0.042057860361182885, 0.053777479615726764, 0.10310807914038048, 0.035564884152021664, 0.05244549725838423, 0.06284541662008727, 0.038744926607261324, 0.04557801027168986, 0.057784547419899676, 0.0895530695955612, 0.030527001698978234, 0.05737515653628573, 0.22294910480420738, 0.06582432311529605, 0.21819882452541012, 0.2020955983283424, 0.07283907679402132, 0.06710712662011396, 0.0592349520616856, 0.051244968868878894, 0.055723001620133876, 0.046156328391588425, 0.053728309666569725, 0.0509408543985903, 0.1127329262747103, 0.08793218998174523, 0.15587917358027442, 0.05605902564054839, 0.044073820101535204, 0.04789172403276019, 0.05158453367601604, 0.22012921592665885, 0.052215738197667, 0.04895841813096867, 0.045791198762459163, 0.07829248356464086, 0.12781890974696977, 0.04799233680558343, 0.07088173805870887, 0.09660766893319528, 0.039167550169384294, 0.04914701536176081, 0.06189108174546717, 0.03806224440127496, 0.05486479458173, 0.06319887132832862, 0.04963029542951583, 0.05070623650078231, 0.0646795060415259, 0.0432760045043379, 0.04257656385992172, 0.05202809340691619, 0.08787174415089585, 0.045533911553068754, 0.06531473737013595, 0.045253332508273965, 0.0550142451184577, 0.09352954868446954, 0.04397243654370055, 0.19661378821349168, 0.037365575227679367, 0.07650444135959933, 0.0784371261717205, 0.05831746738062055, 0.0821050510281217, 0.045435586100873435, 0.24603965990200855, 0.053364170867284365, 0.1597265997519608, 0.2367586729830306, 0.052263519145061825, 0.05272105256483464, 0.06287928722170462, 0.01888868596405862, 0.1928759878904197, 0.07100631418840253, 0.20910601920022326, 0.17373420494098335, 0.056180402750264785, 0.3693858099247548, 0.0323300697678872, 0.3009859430277624, 0.11140951220574695, 0.046435644486419334, 0.05857147167877898, 0.0493728758199393, 0.05276531701237827, 0.06004521681255154, 0.06992185167610611, 0.06201433093571202, 0.04863505892198741, 0.10296242641912046, 0.07305451241140239, 0.07939765895932513, 0.053803228269292264, 0.129 ...

# %%
px.histogram(pd.DataFrame(y_pred_val), x=0)
# Out:
# <div>
#
#
#             <div id="24185014-066f-4b96-a2fc-749ce80cfcef" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("24185014-066f-4b96-a2fc-749ce80cfcef")) {
#                     Plotly.newPlot(
#                         '24185014-066f-4b96-a2fc-749ce80cfcef',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "0=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [0.060135446122378665, 0.060804097445143666, 0.04560213030425472, 0.08070173343088896, 0.05259821622600086, 0.044514192547384965, 0.22788630151393158, 0.0437614649033192, 0.05426867943976275, 0.05917270392172715, 0.1312727339435284, 0.050809701759627304, 0.20279151361078707, 0.05018685138337595, 0.07244501983301413, 0.04372981578846652, 0.06339176681416486, 0.15851992046961214, 0.027196704810069257, 0.055820773965476855, 0.05640439541707504, 0.1985938424117762, 0.046915803446015314, 0.04867189816321113, 0.07626842904620934, 0.04467324846291165, 0.04084136944240897, 0.03940509141017681, 0.04692732677977352, 0.060072659101991215, 0.09622381147357462, 0.04855622119323587, 0.06085018085641268, 0.20312509060523642, 0.1353718426717225, 0.05200167656355575, 0.06445691718480992, 0.05253795585976958, 0.25598031268245075, 0.16539725114923975, 0.09944305801466587, 0.08196739197944175, 0.14157622649830215, 0.13350182725181128, 0.05796153423535697, 0.15348637929307835, 0.16504843644529255, 0.18039419920112915, 0.04182096517955653, 0.056634231532932185, 0.06406094851785757, 0.06178716143964385, 0.08286881014385888, 0.04258532266542599, 0.04348607811695593, 0.05726553798900799, 0.30852311636186575, 0.0608973795757709, 0.11145495355487478, 0.058817006201930845, 0.04778213037340976, 0.059141329811195284, 0.06688883682471183, 0.06141526302754943, 0.37383996902072375, 0.09221800569080611, 0.06251693805738712, 0.050874542154016454, 0.053520978586407884, 0.047342210546482036, 0.054425127743634255, 0.055094471802589064, 0.04949579587328446, 0.05754927709146835, 0.07655326078483435, 0.030021553054899758, 0.062086752854839, 0.02723138034922116, 0.052134286247174096, 0.05778004641582367, 0.036430068577968544, 0.1189226113735653, 0.061137100463059826, 0.04555161507844363, 0.20870923112932538, 0.23779407638586986, 0.06294347592148425, 0.061043386587239686, 0.04116045363335279, 0.06210319887181451, 0.044623630034320474, 0.05388209518233284, 0.04579472277697432, 0.11085877161543971, 0.0935518537023316, 0.05686669439152491, 0.05395742568637337, 0.12455638388578302, 0.06579955110906754, 0.04239061638127129, 0.0626665841708196, 0.05051403764726031, 0.05125238863059657, 0.05449009032715869, 0.05121423657571807, 0.05580846654276969, 0.07957385124700908, 0.054149302229582606, 0.04797751009949771, 0.13050198741949157, 0.06039803379689961, 0.04143557555678645, 0.020869780185658895, 0.056695853498301925, 0.09448039390386355, 0.0492259696398318, 0.0516765345210782, 0.06311805588000746, 0.2084851743376806, 0.04540782769121679, 0.06039998439066041, 0.2774379066591121, 0.056934981201539794, 0.28354320131565935, 0.06172017315545566, 0.041256794580748594, 0.06412747364641458, 0.061611645971623115, 0.023531322118019705, 0.05818089818696171, 0.05007597638595818, 0.17721334863556126, 0.06199517989324147, 0.04897891112548001, 0.054325156450859884, 0.16069767511609756, 0.1755215325171893, 0.06208076702544193, 0.05780527978490344, 0.10215542487123501, 0.036326337284678226, 0.04093003391671354, 0.12253282067173556, 0.1782860119709147, 0.060022508708491185, 0.05987260903972436, 0.137638816684875, 0.038160070459271875, 0.06846829130771552, 0.053664751768106554, 0.1605307886288933, 0.08811490153907081, 0.048746828461206024, 0.07587382667343406, 0.08623425532320336, 0.04136638879040487, 0.05061358460594842, 0.07318048881755673, 0.1964175707483382, 0.05055407236670184, 0.05370166444693624, 0.0431866157183296, 0.04746347137905554, 0.09221883233128425, 0.2238219575113063, 0.08511183986416251, 0.06400556454275008, 0.06401436613488051, 0.03900207464965539, 0.050827908159182124, 0.04824937438060202, 0.06565602446834076, 0.0558620636210703, 0.0599191608749956, 0.08855959223900917, 0.06335788452103416, 0.051037435586536 ...

# %%
px.histogram(pd.DataFrame(y_pred_test), x=0)
# Out:
# <div>
#
#
#             <div id="7c8b71a5-5f47-4a42-bc53-287267d2da8e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7c8b71a5-5f47-4a42-bc53-287267d2da8e")) {
#                     Plotly.newPlot(
#                         '7c8b71a5-5f47-4a42-bc53-287267d2da8e',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "0=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [0.045998523778011655, 0.042756211732485845, 0.039889332885193224, 0.03829959273229948, 0.042178937524633524, 0.0439363468625164, 0.040460749922249614, 0.04421283257786514, 0.039841329068132814, 0.039327700465255126, 0.042881543407062954, 0.037641949153332174, 0.04520121721506019, 0.04385706238568153, 0.02017667367874683, 0.0340154097328002, 0.03522938130521992, 0.028638423398773295, 0.03922283201545635, 0.03833675946620684, 0.04144573265977743, 0.033344026926724724, 0.03828568863206522, 0.03302580757962978, 0.04490386739246296, 0.04022481410701825, 0.02748111764165727, 0.046137958399653366, 0.04287654935941368, 0.03928578983176749, 0.046244626071948645, 0.0409466018729846, 0.04075761678128791, 0.055219696588534414, 0.037239833076142474, 0.038931312667498316, 0.043081268724191296, 0.05013431132068794, 0.05443905880026943, 0.047058948549448996, 0.04146700466493132, 0.03949547550940861, 0.03396830220435632, 0.0387495914732988, 0.058457333844542804, 0.03581039983916792, 0.03559006559683803, 0.04561954532304186, 0.036150785223557594, 0.023247971724847, 0.04565962765231262, 0.04333548832315847, 0.029264521326949164, 0.03652096621381591, 0.04834972817249523, 0.032390642503863046, 0.04614929350973128, 0.038104159457875715, 0.05177903577506881, 0.03705085967934224, 0.0447260064759145, 0.04856190688706684, 0.04789692201932431, 0.04463942132191778, 0.04564697083268689, 0.03701917327864278, 0.04231060530251171, 0.026883710600622758, 0.0404069696145755, 0.0442566260749853, 0.04916272534458447, 0.05016163458589863, 0.03434983915327723, 0.04379064780978853, 0.042782394881512954, 0.04236783568297381, 0.03485907233384891, 0.04445479270798383, 0.02418054593022123, 0.037063099865878156, 0.039838899859099365, 0.04638939553445442, 0.044986750950559984, 0.04262590432664769, 0.03125455681796232, 0.040890811638446115, 0.04387097493726423, 0.03946725434340137, 0.031188332234104964, 0.04873029144110743, 0.03749951378769478, 0.0331716816799711, 0.037961271303369216, 0.038880425787282145, 0.040608088132147016, 0.03564560110150062, 0.037003314669692505, 0.032391675726265015, 0.03172471397365591, 0.04653641332635262, 0.04375029425803692, 0.0541600087897684, 0.04017568581534392, 0.04044974903142505, 0.03671046643678544, 0.034016146077022906, 0.027127990468244344, 0.014440431112037563, 0.03665880152813702, 0.04871775313617756, 0.03499408892404101, 0.03710312152507016, 0.03110012475128282, 0.04157945587758981, 0.04975356805160129, 0.03124521223862728, 0.043282015961150104, 0.047391747257105335, 0.04094049598056691, 0.04636323719890495, 0.026439355869916574, 0.04674628055294806, 0.02168038938891522, 0.034581623293359516, 0.056567158699001766, 0.04114810422979761, 0.021514458449558856, 0.021943423390022865, 0.04978616997409527, 0.04892743378320347, 0.03361893424588636, 0.05197891873064524, 0.041667867669465446, 0.03397350022386785, 0.04817576964710777, 0.03002988810539267, 0.04302478718937632, 0.046098111766588755, 0.023291346606893228, 0.04193714848362491, 0.04003842924949235, 0.032151988999895256, 0.035697789501982186, 0.03241227599894146, 0.048382042612834346, 0.04233113049021749, 0.040773277375404884, 0.017652645330998654, 0.03987533899416102, 0.0357012413468206, 0.0529851003254008, 0.07150627708736866, 0.03775609811010536, 0.03374066118615181, 0.048649057044048385, 0.02849423429881541, 0.016509117131419088, 0.03784785788694824, 0.036586748601867974, 0.05863929312957812, 0.05628880507021204, 0.055566562172759855, 0.04314448835907159, 0.02560147925069807, 0.05021576182766892, 0.04624605834383345, 0.033908753763071245, 0.03314115573293705, 0.04218065484027713, 0.043452847497726196, 0.04478818594449974, 0.04555857107766057, 0.05176720067873331, 0.036773653812117967, 0.04644182241858588, 0.0 ...
