# %%
# Scientific libraries		              
import numpy as np		              
import scipy as sp		              
import pandas as pd		              
import json		              
import missingno as msno		              

# Loading Plotting Modules		              
import matplotlib		              
import matplotlib.pyplot as plt		              
import seaborn as sns		              
# %matplotlib inline		              
import chart_studio.plotly as py		              
import plotly.figure_factory as ff		              
import plotly.graph_objects as go		              
import plotly.express as px		              
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot		              
init_notebook_mode(connected=True)		              
		              
import os		              
import gc
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Setting Data Frame Options                      
pd.set_option('display.max_rows', 40)                      
pd.set_option('display.max_columns', 50)                      
pd.set_option('display.width', 100)                      
pd.set_option('display.max_colwidth', 100)                      

# Setting Plot Configuration                      
sns.set(rc={'figure.figsize':(19,11)}, style = 'white')

# %%
train = pd.read_csv('../../eda/outputs/imputed_c4_scaled_train.csv')                
m, n = train.shape                
print('Data Frame: {} x {}'.format(m,n))                
train.head()
# Out:
# Data Frame: 3865 x 79
#    existence expectancy index  existence expectancy at birth  Gross income per capita  \
# 0                    0.391903                       0.436379                 0.180134
# 1                    0.577139                       0.706534                 0.200356
# 2                    0.422009                       0.382670                 0.056671
# 3                    0.320718                       0.273319                 0.133938
# 4                    0.746424                       0.718583                 0.536780
#
#    Income Index  Expected years of education (galactic years)  \
# 0      0.330914                                      0.191779
# 1      0.523652                                      0.296773
# 2      0.194190                                      0.217680
# 3      0.297991                                      0.202692
# 4      0.784350                                      0.431892
#
#    Mean years of education (galactic years)  Intergalactic Development Index (IDI)  \
# 0                                  0.357754                               0.344793
# 1                                  0.164296                               0.583800
# 2                                  0.213422                               0.203753
# 3                                  0.338361                               0.217090
# 4                                  0.657389                               0.663786
#
#    Education Index  Intergalactic Development Index (IDI), Rank  \
# 0         0.337492                                     0.593450
# 1         0.257466                                     0.538425
# 2         0.161114                                     0.747860
# 3         0.322132                                     0.620007
# 4         0.674673                                     0.243647
#
#    Population using at least basic drinking-water services (%)  \
# 0                                                     0.355888
# 1                                                     0.614669
# 2                                                     0.279038
# 3                                                     0.321512
# 4                                                     0.806120
#
#    Population using at least basic sanitation services (%)  Gross capital formation (% of GGP)  \
# 0                                                 0.277196                            0.474812
# 1                                                 0.594579                            0.447638
# 2                                                 0.237096                            0.206892
# 3                                                 0.250549                            0.373955
# 4                                                 0.780922                            0.424333
#
#    Population, total (millions)  Population, urban (%)  \
# 0                      0.100170               0.029288
# 1                      0.069502               0.608693
# 2                      0.053043               0.334331
# 3                      0.057994               0.250602
# 4                      0.094456               0.731785
#
#    Mortality rate, under-five (per 1,000 live births)  \
# 0                                            0.393048
# 1                                            0.305141
# 2                                            0.595041
# 3                                            0.734030
# 4                                            0.070185
#
#    Mortality rate, infant (per 1,000 live births)  \
# 0                                        0.613240
# 1                                        0.278800
# 2                                        0.636431
# 3                                        0.924904
# 4                                        0.226070
#
#    Old age dependency ratio (old age (65 and older) per 100 creatures (ages 15-64))  \
# 0                                                                          0.169169
# 1                                                                          0.182756
# 2                                                                          0.243444
# 3                                                                          0.180379
# 4                                                                          0.442926
#
#    Population, ages 15–64 (millions)  Population, ages 65 and older (millions)  \
# 0                           0.103254                                  0.124460
# 1                           0.115696                                  0.122159
# 2                           0.114713                                  0.099141
# 3                           0.152305                                  0.111382
# 4                           0.120113                                  0.118572
#
#    Life expectancy at birth, male (galactic years)  \
# 0                                         0.316953
# 1                                         0.544774
# 2                                         0.360129
# 3                                         0.201810
# 4                                         0.813409
#
#    Life expectancy at birth, female (galactic years)  Population, under age 5 (millions)  \
# 0                                           0.462997                            0.074950
# 1                                           0.574020                            0.067586
# 2                                           0.291935                            0.131685
# 3                                           0.224279                            0.133741
# 4                                           0.701534                            0.107015
#
#    Young age (0-14) dependency ratio (per 100 creatures ages 15-64)  \
# 0                                                          0.671548
# 1                                                          0.594823
# 2                                                          0.795227
# 3                                                          0.667121
# 4                                                          0.327374
#
#    Adolescent birth rate (births per 1,000 female creatures ages 15-19)  \
# 0                                                              0.581831
# 1                                                              0.346862
# 2                                                              0.784964
# 3                                                              0.670240
# 4                                                              0.169402
#
#    Total unemployment rate (female to male ratio)  ...  \
# 0                                        0.055885  ...
# 1                                        0.063764  ...
# 2                                        0.049980  ...
# 3                                        0.053614  ...
# 4                                        0.060880  ...
#
#    Estimated gross galactic income per capita, female  \
# 0                                            0.157990
# 1                                            0.195096
# 2                                            0.147063
# 3                                            0.131608
# 4                                            0.654762
#
#    Rural population with access to electricity (%)  \
# 0                                         0.234921
# 1                                         0.622902
# 2                                         0.213918
# 3                                         0.229581
# 4                                         0.769611
#
#    Domestic credit provided by financial sector (% of GGP)  \
# 0                                                 0.191719
# 1                                                 0.160763
# 2                                                 0.192623
# 3                                                 0.198887
# 4                                                 0.335516
#
#    Population with at least some secondary education, female (% ages 25 and older)  \
# 0                                                                         0.223137
# 1                                                                         0.339497
# 2                                                                         0.237297
# 3                                                                         0.216708
# 4                                                                         0.475970
#
#    Population with at least some secondary education, male (% ages 25 and older)  \
# 0                                                                       0.283052
# 1                                                                       0.317052
# 2                                                                       0.301120
# 3                                                                       0.301552
# 4                                                                       0.453048
#
#    Gross fixed capital formation (% of GGP)  Remittances, inflows (% of GGP)  \
# 0                                  0.515809                         0.053530
# 1                                  0.336151                         0.036478
# 2                                  0.178143                         0.024396
# 3                                  0.324499                         0.056827
# 4                                  0.357215                         0.058588
#
#    Population with at least some secondary education (% ages 25 and older)  \
# 0                                                                 0.238422
# 1                                                                 0.250016
# 2                                                                 0.101404
# 3                                                                 0.240170
# 4                                                                 0.406833
#
#    Intergalactic inbound tourists (thousands)  \
# 0                                    0.091255
# 1                                    0.092411
# 2                                    0.084511
# 3                                    0.087511
# 4                                    0.087624
#
#    Gross enrolment ratio, primary (% of primary under-age population)  \
# 0                                                            0.374999
# 1                                                            0.596507
# 2                                                            0.426323
# 3                                                            0.334398
# 4                                                            0.555963
#
#    Respiratory disease incidence (per 100,000 people)  \
# 0                                            0.324717
# 1                                            0.229269
# 2                                            0.298794
# 3                                            0.328659
# 4                                            0.131623
#
#    Interstellar phone subscriptions (per 100 people)  \
# 0                                           0.205774
# 1                                           0.232885
# 2                                           0.141450
# 3                                           0.130522
# 4                                           0.594284
#
#    Interstellar Data Net users, total (% of population)  Current health expenditure (% of GGP)  \
# 0                                              0.203008                               0.219118
# 1                                              0.230264                               0.226282
# 2                                              0.191675                               0.255438
# 3                                              0.190795                               0.567732
# 4                                              0.574955                               0.369993
#
#    Intergalactic Development Index (IDI), female  Intergalactic Development Index (IDI), male  \
# 0                                       0.323646                                     0.293293
# 1                                       0.513055                                     0.517547
# 2                                       0.264287                                     0.191852
# 3                                       0.239026                                     0.211705
# 4                                       0.760254                                     0.750144
#
#    Gender Development Index (GDI)  Intergalactic Development Index (IDI), female, Rank  \
# 0                        0.684113                                             0.599405
# 1                        0.686377                                             0.610330
# 2                        0.641791                                             0.802950
# 3                        0.643656                                             0.580420
# 4                        0.853754                                             0.263455
#
#    Intergalactic Development Index (IDI), male, Rank  Adjusted net savings   \
# 0                                           0.578120               0.682786
# 1                                           0.543835               0.686677
# 2                                           0.803173               0.700804
# 3                                           0.586058               0.668301
# 4                                           0.253005               0.802429
#
#    Creature Immunodeficiency Disease prevalence, adult (% ages 15-49), total  \
# 0                                                                   0.196825
# 1                                                                   0.146853
# 2                                                                   0.204769
# 3                                                                   0.188288
# 4                                                                   0.180325
#
#    Private galaxy capital flows (% of GGP)  Gender Inequality Index (GII)    galaxy         y
# 0                                 0.917897                       0.766789  0.047759  0.052590
# 1                                 0.911980                       0.654790  0.057951  0.059868
# 2                                 0.916773                       0.796380  0.042337  0.050449
# 3                                 0.917065                       0.782493  0.041047  0.049394
# 4                                 0.916510                       0.318590  0.208920  0.154247
#
# [5 rows x 79 columns]

# %%
test = pd.read_csv('../../eda/outputs/imputed_c4_scaled_test.csv')
m, n = test.shape                
print('Data Frame: {} x {}'.format(m,n))                
test.head()
# Out:
# Data Frame: 890 x 78
#    existence expectancy index  existence expectancy at birth  Gross income per capita  \
# 0                    0.223149                       0.261673                 0.081769
# 1                    0.295267                       0.347279                 0.023537
# 2                    0.325719                       0.379784                 0.183134
# 3                    0.330545                       0.388440                 0.135444
# 4                    0.352414                       0.320083                 0.159303
#
#    Income Index  Expected years of education (galactic years)  \
# 0      0.281643                                      0.285646
# 1      0.358363                                      0.148548
# 2      0.282857                                      0.344409
# 3      0.510055                                      0.337444
# 4      0.213648                                      0.284707
#
#    Mean years of education (galactic years)  Intergalactic Development Index (IDI)  \
# 0                                  0.512036                               0.285081
# 1                                  0.197493                               0.233549
# 2                                  0.234078                               0.282610
# 3                                  0.475187                               0.435767
# 4                                  0.259580                               0.267943
#
#    Education Index  Intergalactic Development Index (IDI), Rank  \
# 0         0.339331                                     0.831239
# 1         0.203839                                     0.885923
# 2         0.274409                                     0.894031
# 3         0.308930                                     0.754044
# 4         0.361698                                     0.838913
#
#    Population using at least basic drinking-water services (%)  \
# 0                                                     0.698324
# 1                                                     0.218971
# 2                                                     0.248289
# 3                                                     0.358968
# 4                                                     0.355017
#
#    Population using at least basic sanitation services (%)  Gross capital formation (% of GGP)  \
# 0                                                 0.355976                            0.197936
# 1                                                 0.236344                            0.404853
# 2                                                 0.254133                            0.386102
# 3                                                 0.336148                            0.423028
# 4                                                 0.270191                            0.174589
#
#    Population, total (millions)  Population, urban (%)  \
# 0                      0.103516               0.470690
# 1                      0.097937               0.291136
# 2                      0.099930               0.287194
# 3                      0.102746               0.415630
# 4                      0.150680               0.393780
#
#    Mortality rate, under-five (per 1,000 live births)  \
# 0                                            0.382672
# 1                                            0.434841
# 2                                            0.404629
# 3                                            0.362385
# 4                                            0.576674
#
#    Mortality rate, infant (per 1,000 live births)  \
# 0                                        0.466538
# 1                                        0.506936
# 2                                        0.468073
# 3                                        0.397285
# 4                                        0.613892
#
#    Old age dependency ratio (old age (65 and older) per 100 creatures (ages 15-64))  \
# 0                                                                          0.172478
# 1                                                                          0.185795
# 2                                                                          0.184625
# 3                                                                          0.162909
# 4                                                                          0.202759
#
#    Population, ages 15–64 (millions)  Population, ages 65 and older (millions)  \
# 0                           0.103171                                  0.114102
# 1                           0.107588                                  0.116823
# 2                           0.108145                                  0.116891
# 3                           0.099087                                  0.112577
# 4                           0.100490                                  0.066797
#
#    Life expectancy at birth, male (galactic years)  \
# 0                                         0.303145
# 1                                         0.313677
# 2                                         0.380257
# 3                                         0.383687
# 4                                         0.354488
#
#    Life expectancy at birth, female (galactic years)  Population, under age 5 (millions)  \
# 0                                           0.315039                            0.121412
# 1                                           0.317044                            0.109599
# 2                                           0.325315                            0.113637
# 3                                           0.347517                            0.115578
# 4                                           0.369471                            0.118236
#
#    Young age (0-14) dependency ratio (per 100 creatures ages 15-64)  \
# 0                                                          0.735960
# 1                                                          0.786487
# 2                                                          0.789005
# 3                                                          0.724501
# 4                                                          0.771346
#
#    Adolescent birth rate (births per 1,000 female creatures ages 15-19)  \
# 0                                                              0.564175
# 1                                                              0.614688
# 2                                                              0.597515
# 3                                                              0.512371
# 4                                                              0.537664
#
#    Total unemployment rate (female to male ratio)  ...  \
# 0                                        0.056596  ...
# 1                                        0.054512  ...
# 2                                        0.054085  ...
# 3                                        0.060768  ...
# 4                                        0.053521  ...
#
#    Estimated gross galactic income per capita, male  \
# 0                                          0.103798
# 1                                          0.103189
# 2                                          0.111775
# 3                                          0.120195
# 4                                          0.093024
#
#    Estimated gross galactic income per capita, female  \
# 0                                            0.165773
# 1                                            0.159326
# 2                                            0.168655
# 3                                            0.203256
# 4                                            0.215890
#
#    Rural population with access to electricity (%)  \
# 0                                         0.371389
# 1                                         0.224915
# 2                                         0.220301
# 3                                         0.314744
# 4                                         0.280913
#
#    Domestic credit provided by financial sector (% of GGP)  \
# 0                                                 0.226804
# 1                                                 0.202339
# 2                                                 0.203169
# 3                                                 0.202032
# 4                                                 0.209716
#
#    Population with at least some secondary education, female (% ages 25 and older)  \
# 0                                                                         0.357202
# 1                                                                         0.192795
# 2                                                                         0.204484
# 3                                                                         0.335615
# 4                                                                         0.145851
#
#    Population with at least some secondary education, male (% ages 25 and older)  \
# 0                                                                       0.414912
# 1                                                                       0.197576
# 2                                                                       0.252744
# 3                                                                       0.357082
# 4                                                                       0.333797
#
#    Gross fixed capital formation (% of GGP)  Remittances, inflows (% of GGP)  \
# 0                                  0.148443                         0.064476
# 1                                  0.334606                         0.054913
# 2                                  0.333695                         0.055835
# 3                                  0.368215                         0.052951
# 4                                  0.101534                         0.062461
#
#    Population with at least some secondary education (% ages 25 and older)  \
# 0                                                                 0.373681
# 1                                                                 0.201713
# 2                                                                 0.237795
# 3                                                                 0.337196
# 4                                                                 0.237129
#
#    Intergalactic inbound tourists (thousands)  \
# 0                                    0.090410
# 1                                    0.089152
# 2                                    0.087506
# 3                                    0.089707
# 4                                    0.089961
#
#    Gross enrolment ratio, primary (% of primary under-age population)  \
# 0                                                            0.479448
# 1                                                            0.306161
# 2                                                            0.545510
# 3                                                            0.555967
# 4                                                            0.394433
#
#    Respiratory disease incidence (per 100,000 people)  \
# 0                                            0.281987
# 1                                            0.248583
# 2                                            0.237936
# 3                                            0.305587
# 4                                            0.325619
#
#    Interstellar phone subscriptions (per 100 people)  \
# 0                                           0.273287
# 1                                           0.179999
# 2                                           0.203944
# 3                                           0.270666
# 4                                           0.241243
#
#    Interstellar Data Net users, total (% of population)  Current health expenditure (% of GGP)  \
# 0                                              0.222402                               0.260025
# 1                                              0.205893                               0.244112
# 2                                              0.210110                               0.259607
# 3                                              0.222756                               0.239138
# 4                                              0.275256                               0.237723
#
#    Intergalactic Development Index (IDI), female  Intergalactic Development Index (IDI), male  \
# 0                                       0.377036                                     0.341749
# 1                                       0.270051                                     0.238774
# 2                                       0.339556                                     0.269320
# 3                                       0.463486                                     0.354120
# 4                                       0.381321                                     0.283148
#
#    Gender Development Index (GDI)  Intergalactic Development Index (IDI), female, Rank  \
# 0                        0.717844                                             0.797097
# 1                        0.653919                                             0.810743
# 2                        0.719630                                             0.794933
# 3                        0.752725                                             0.766830
# 4                        0.622986                                             0.879547
#
#    Intergalactic Development Index (IDI), male, Rank  Adjusted net savings   \
# 0                                           0.786682               0.636931
# 1                                           0.826771               0.678842
# 2                                           0.800842               0.666669
# 3                                           0.753798               0.700512
# 4                                           0.939963               0.611172
#
#    Creature Immunodeficiency Disease prevalence, adult (% ages 15-49), total  \
# 0                                                                   0.233326
# 1                                                                   0.206223
# 2                                                                   0.218372
# 3                                                                   0.232684
# 4                                                                   0.235344
#
#    Private galaxy capital flows (% of GGP)  Gender Inequality Index (GII)    galaxy
# 0                                 0.913618                       0.738867  0.045937
# 1                                 0.914100                       0.783630  0.042850
# 2                                 0.915718                       0.736398  0.042850
# 3                                 0.916179                       0.709852  0.042614
# 4                                 0.915736                       0.794609  0.042337
#
# [5 rows x 78 columns]

# %%
import h2o
from h2o.frame import H2OFrame
from h2o.automl import H2OAutoML; h2o.init()
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 ..... not found.
# Attempting to start a local H2O server...
# ; Java HotSpot(TM) 64-Bit Server VM (build 25.211-b12, mixed mode)
#   Starting server from C:\Python38\Lib\site-packages\h2o\backend\bin\h2o.jar
#   Ice root: C:\Users\devri\AppData\Local\Temp\tmpnrj0l6yp
#   JVM stdout: C:\Users\devri\AppData\Local\Temp\tmpnrj0l6yp\h2o_devri_started_from_python.out
#   JVM stderr: C:\Users\devri\AppData\Local\Temp\tmpnrj0l6yp\h2o_devri_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  ---------------------------------------------------------
# H2O_cluster_uptime:         02 secs
# H2O_cluster_timezone:       Asia/Istanbul
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.30.0.3
# H2O_cluster_version_age:    1 month and 7 days
# H2O_cluster_name:           H2O_from_python_devri_pfd0rg
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    7.101 Gb
# H2O_cluster_total_cores:    16
# H2O_cluster_allowed_cores:  16
# H2O_cluster_status:         accepting new members, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# H2O_API_Extensions:         Amazon S3, Algos, AutoML, Core V3, TargetEncoder, Core V4
# Python_version:             3.8.0 final
# --------------------------  ---------------------------------------------------------

# %%
def plot_lgb_history(history):
    for i, key in enumerate(history.evals_result_):
        if i == 0:
            res = pd.DataFrame(history.evals_result_[key])
            res['index'] = np.arange(len(history.evals_result_[key]['l2']))
            res['type'] = key
        temp = pd.DataFrame(history.evals_result_[key])
        temp['type'] = key
        temp['index'] = np.arange(len(history.evals_result_[key]['l2']))
        
        res = res.append(temp, ignore_index=True)
        del temp; gc.collect()
    
    fig = px.scatter(data_frame=res, x='index', y='l2', color='type',
                 title='Learning curve')
    fig.show()

# %%
y = 'y'
Xn = train.columns.drop(y).tolist()

# %%
X_train, X_val, y_train, y_val = train_test_split(train[X].to_numpy(), train[y].to_numpy(),
                                                  test_size=0.25, random_state=42)
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((2898, 78), (967, 78), (2898,), (967,))

# %%
train_set = pd.DataFrame(X_train)
train_set = train_set.add_prefix('feature_')
train_set['y'] = y_train

val_set = pd.DataFrame(X_val)
val_set = val_set.add_prefix('feature_')
val_set['y'] = y_val

# %%
X = train_set.columns.drop(y).tolist()

# %%
train_set = H2OFrame(train_set)
val_set = H2OFrame(val_set)

y_train = train_set[y].as_data_frame().values
y_val = val_set[y].as_data_frame().values

# No need for eval set
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %% [markdown]
# **Examples**
#
#     >>> import h2o
#     >>> from h2o.automl import H2OAutoML
#     >>> h2o.init()
#     >>> # Import a sample binary outcome train/test set into H2O
#     >>> train = h2o.import_file("https://s3.amazonaws.com/erin-data/higgs/higgs_train_10k.csv")
#     >>> test = h2o.import_file("https://s3.amazonaws.com/erin-data/higgs/higgs_test_5k.csv")
#     >>> # Identify the response and set of predictors
#     >>> y = "response"
#     >>> x = list(train.columns)  #if x is defined as all columns except the response, then x is not required
#     >>> x.remove(y)
#     >>> # For binary classification, response should be a factor
#     >>> train[y] = train[y].asfactor()
#     >>> test[y] = test[y].asfactor()
#     >>> # Run AutoML for 30 seconds
#     >>> aml = H2OAutoML(max_runtime_secs = 30)
#     >>> aml.train(x = x, y = y, training_frame = train)
#     >>> # Print Leaderboard (ranked by xval metrics)
#     >>> aml.leaderboard
#     >>> # (Optional) Evaluate performance on a test set
#     >>> perf = aml.leader.model_performance(test)
#     >>> perf.auc()

# %%
# num_leaves << 2^(max_depth)

aml = H2OAutoML(
    nfolds=0, # if nfolds != 0, then validation_frame in train() is ignored.
    balance_classes=False,
    class_sampling_factors=None,
    max_after_balance_size=5.0,
    max_runtime_secs=300,
    max_runtime_secs_per_model=None,
    max_models=None,
    stopping_metric='AUTO',
    stopping_tolerance=None,
    stopping_rounds=3,
    seed=None,
    project_name=None,
    exclude_algos=None,
    include_algos=None,
    exploitation_ratio=0,
    modeling_plan=None,
    monotone_constraints=None,
    algo_parameters=None,
    keep_cross_validation_predictions=False,
    keep_cross_validation_models=False,
    keep_cross_validation_fold_assignment=False,
    sort_metric='RMSE',
    export_checkpoints_dir=None,
    verbosity='warn'
)

aml.train(x=X, y=y,
                training_frame=train_set,
                validation_frame=val_set
    )

y_pred_train = aml.predict(train_set[X]).as_data_frame().values
y_pred_val = aml.predict(val_set[X]).as_data_frame().values

train_rmse = mean_squared_error(y_true=y_train, y_pred=y_pred_train, squared=False)
val_rmse = mean_squared_error(y_true=y_val, y_pred=y_pred_val, squared=False)
print('#'*60)
print(f'RMSE Train: {train_rmse: .8f}')
print(f'RMSE Valid: {val_rmse: .8f}\tRatio (val/train): {val_rmse/train_rmse: .5f}')
# Out:
# AutoML progress: |
# 00:11:07.593: AutoML: XGBoost is not available; skipping it.
#
# ████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%

# Out:
# gbm prediction progress: |████████████████████████████████████████████████| 100%

# %%
pred_output = pd.DataFrame()
pred_output['y_pred'] = y_pred_test.as_data_frame().to_numpy().ravel()
pred_output.reset_index(inplace=True)
pred_output.rename(columns = {
    "index": "Index"
    }, inplace=True)
pred_output
# Out:
#      Index    y_pred
# 0        0  0.043790
# 1        1  0.040864
# 2        2  0.040544
# 3        3  0.040444
# 4        4  0.033149
# ..     ...       ...
# 885    885  0.050543
# 886    886  0.057326
# 887    887  0.076358
# 888    888  0.069972
# 889    889  0.052088
#
# [890 rows x 2 columns]

# %%
os.makedirs('../outputs', exist_ok=True)
from datetime import datetime
ts_now = datetime.now().strftime('%Y%m%d_%H%M%S')
pred_output.to_csv(f'../outputs/y_pred_h2o_{ts_now}.csv', index=False)

# %%
print("Train samples:", y_pred_train.shape[0])
print("Validation samples:", y_pred_val.shape[0])
print("Test samples:", y_pred_test.shape[0])
# Out:
# Train samples: 2898
# Validation samples: 967
# Test samples: 890

# %%
px.histogram(pd.DataFrame(y_pred_train), x=0)
# Out:
# <div>
#
#
#             <div id="5a4ec7dc-d845-4bfd-899d-74617c3c53c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5a4ec7dc-d845-4bfd-899d-74617c3c53c0")) {
#                     Plotly.newPlot(
#                         '5a4ec7dc-d845-4bfd-899d-74617c3c53c0',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "0=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [0.0495321752389398, 0.08684219501208443, 0.046984488354385366, 0.04841991308700497, 0.041446968447348485, 0.021282186217834148, 0.04155090246922808, 0.048134211413002635, 0.27009349338456695, 0.0619665938401138, 0.1580400639365703, 0.0695786258502292, 0.05096205411814733, 0.06298270473723985, 0.13139125819884864, 0.07719817078589382, 0.08551052919426891, 0.07002932599232534, 0.04562110978622766, 0.04462860277590405, 0.1728477829731244, 0.044625810219261236, 0.05052883690496199, 0.06294844808224095, 0.18112092796670504, 0.06356559901155631, 0.061165588663814364, 0.05781228222395182, 0.05714627630027533, 0.0573114238170572, 0.04620694390223687, 0.10784870554164423, 0.054208056999189264, 0.07547433253216948, 0.05605635820609475, 0.1659593327805194, 0.06866396368320946, 0.06634599338122169, 0.06593826972096192, 0.043128666893539634, 0.05008571270870985, 0.04293035852417657, 0.14667885158405874, 0.11075334314557747, 0.05042017421010567, 0.13189889085697612, 0.20789934567980847, 0.04260406368439615, 0.0845416312388377, 0.055968668711105035, 0.056701747175455036, 0.05588703741568932, 0.20727083585095127, 0.05425822925603793, 0.0474384676130509, 0.05149798826483018, 0.1754502388407698, 0.06428215038909255, 0.05741454389977005, 0.06476374217322953, 0.04729174781502973, 0.04788541494599738, 0.13592353291412249, 0.026246566939493867, 0.2321694141600997, 0.07364667079957851, 0.0848385385471627, 0.08658529908712151, 0.1903015868072114, 0.19414879693883588, 0.07069727547087976, 0.045822596332530136, 0.2897418997153832, 0.06421622044047379, 0.05248932704148754, 0.09292766597730204, 0.053058974342209485, 0.06782297362451825, 0.07502235869793847, 0.048674648489852895, 0.0676031077272253, 0.053142215238724734, 0.2340424347969215, 0.2346390287423244, 0.054970703608023225, 0.045748838672625115, 0.04820467515401358, 0.03149418447287897, 0.07643698832396492, 0.055302425270272376, 0.1398330485395459, 0.0729528939896252, 0.2143289139987726, 0.06636163753751388, 0.17024437362488495, 0.08112940933858934, 0.14070995775455486, 0.048690752899097266, 0.19138899307037854, 0.03597215521631622, 0.06536919649056724, 0.041422959042850184, 0.041592418486063966, 0.05899