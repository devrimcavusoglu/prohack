# %%
# Scientific libraries		              
import numpy as np		              
import scipy as sp		              
import pandas as pd		              
import json		              
import missingno as msno		              

# Loading Plotting Modules		              
import matplotlib		              
import matplotlib.pyplot as plt		              
import seaborn as sns		              
# %matplotlib inline		              
import chart_studio.plotly as py		              
import plotly.figure_factory as ff		              
import plotly.graph_objects as go		              
import plotly.express as px		              
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot		              
init_notebook_mode(connected=True)		              
		              
import os		              
import gc
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Setting Data Frame Options                      
pd.set_option('display.max_rows', 40)                      
pd.set_option('display.max_columns', 50)                      
pd.set_option('display.width', 100)                      
pd.set_option('display.max_colwidth', 100)                      

# Setting Plot Configuration                      
sns.set(rc={'figure.figsize':(19,11)}, style = 'white')

# %%
train = pd.read_csv('./outputs/imputed_train_mf.csv')                
m_train, n_train = train.shape                
print('Data Frame: {} x {}'.format(m_train,n_train))                
train.head()
# Out:
# Data Frame: 3865 x 80
#    galactic year  existence expectancy index  existence expectancy at birth  \
# 0       990025.0                    0.759989                      72.020628
# 1       990025.0                    0.588206                      62.473456
# 2       990025.0                    1.063381                      93.576404
# 3       990025.0                    0.887711                      72.296275
# 4       990025.0                    1.065573                      84.289074
#
#    Gross income per capita  Income Index  Expected years of education (galactic years)  \
# 0             18445.323465      0.647025                                     13.819287
# 1             12072.373320      0.614855                                      8.368089
# 2             34891.830736      0.945705                                     15.452324
# 3             44701.171827      1.017183                                     13.418461
# ...

# %%
test = pd.read_csv('./outputs/imputed_test_mf.csv')                
m_test, n_test = test.shape                
print('Data Frame: {} x {}'.format(m_test,n_test))                
test.head()
# Out:
# Data Frame: 890 x 79
#    galactic year  existence expectancy index  existence expectancy at birth  \
# 0      1007012.0                    0.868360                      72.982208
# 1      1007012.0                    0.772696                      73.590698
# 2      1007012.0                    0.941941                      81.973436
# 3      1007012.0                    1.079857                      89.351427
# 4      1007012.0                    1.079557                      94.084539
#
#    Gross income per capita  Income Index  Expected years of education (galactic years)  \
# 0             19198.499040      0.700413                                     16.145285
# 1             18345.350181      0.684405                                     12.167872
# 2             26708.317145      0.925563                                     18.175905
# 3             54738.000742      1.016415                                     19.927563
# ...

# %%
df = train.append(test, ignore_index=True)
df
# Out:
#       galactic year  existence expectancy index  existence expectancy at birth  \
# 0          990025.0                    0.759989                      72.020628
# 1          990025.0                    0.588206                      62.473456
# 2          990025.0                    1.063381                      93.576404
# 3          990025.0                    0.887711                      72.296275
# 4          990025.0                    1.065573                      84.289074
# ...             ...                         ...                            ...
# 4750      1016064.0                    0.850609                      70.164964
# 4751      1016064.0                    0.808027                      72.909090
# 4752      1016064.0                    1.012209                      82.695963
# 4753      1016064.0                    0.704373                      62.578774
# 4754      1016064.0                    0.771783                      62.266666
#
# ...

# %%
# %%latex
#
# Scaling by StandardScaler, standardizing (scaling $X_{i}$ s.t $X_{i}$~N(0,1) for all i) every feature.
# Out:
# Scaling by StandardScaler, standardizing (scaling $X_{i}$ s.t $X_{i}$~N(0,1) for all i) every feature.

# %%
from sklearn.preprocessing import StandardScaler

# %%
df_scaled = df.drop(['galactic year', 'galaxy', 'y'], axis=1)
cols = df_scaled.columns

# %%
scaler = StandardScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df_scaled), columns=cols)
df_scaled
# Out:
#       existence expectancy index  existence expectancy at birth  Gross income per capita  \
# 0                      -0.768696                      -0.521320                -0.720678
# 1                      -1.850364                      -1.449645                -1.060701
# 2                       1.141680                       1.574668                 0.156809
# 3                       0.035534                      -0.494518                 0.680176
# 4                       1.155480                       0.671609                 1.092055
# ...                          ...                            ...                      ...
# 4750                   -0.198088                      -0.701757                -0.539758
# 4751                   -0.466216                      -0.434930                -0.243287
# 4752                    0.819465                       0.516702                -0.515527
# ...

# %%
df_scaled['galactic year'] = df['galactic year']
df_scaled['galaxy'] = df['galaxy']
df_scaled['y'] = df['y']
df_scaled
# Out:
#       existence expectancy index  existence expectancy at birth  Gross income per capita  \
# 0                      -0.768696                      -0.521320                -0.720678
# 1                      -1.850364                      -1.449645                -1.060701
# 2                       1.141680                       1.574668                 0.156809
# 3                       0.035534                      -0.494518                 0.680176
# 4                       1.155480                       0.671609                 1.092055
# ...                          ...                            ...                      ...
# 4750                   -0.198088                      -0.701757                -0.539758
# 4751                   -0.466216                      -0.434930                -0.243287
# 4752                    0.819465                       0.516702                -0.515527
# ...

# %%
train_scaled = df_scaled[:-m_test].copy()
test_scaled = df_scaled[-m_test:].copy()
train_scaled.shape, test_scaled.shape
# Out:
# ((3865, 80), (890, 80))

# %%
train_scaled.to_csv('./outputs/imputed_scaled_train.csv', index=False)
test_scaled.to_csv('./outputs/imputed_scaled_test.csv', index=False)
