# %%
# Scientific libraries		              
import numpy as np		              
import scipy as sp		              
import pandas as pd		              
import json		              
import missingno as msno		              

# Loading Plotting Modules		              
import matplotlib		              
import matplotlib.pyplot as plt		              
import seaborn as sns		              
# %matplotlib inline		              
import chart_studio.plotly as py		              
import plotly.figure_factory as ff		              
import plotly.graph_objects as go		              
import plotly.express as px		              
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot		              
init_notebook_mode(connected=True)		              
		              
import os		              
import gc
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Setting Data Frame Options                      
pd.set_option('display.max_rows', 150)                      
pd.set_option('display.max_columns', 50)                      
pd.set_option('display.width', 100)                      
pd.set_option('display.max_colwidth', 100)                      

# Setting Plot Configuration                      
sns.set(rc={'figure.figsize':(19,11)}, style = 'white')

# %%
train = pd.read_csv('../../data/train.csv')  
m, n = train.shape                
print('Data Frame: {} x {}'.format(m,n))                
train.head()
# Out:
# Data Frame: 3865 x 80
#    galactic year                        galaxy  existence expectancy index  \
# 0         990025  Large Magellanic Cloud (LMC)                    0.628657
# 1         990025              Camelopardalis B                    0.818082
# 2         990025                       Virgo I                    0.659443
# 3         990025            UGC 8651 (DDO 181)                    0.555862
# 4         990025                  Tucana Dwarf                    0.991196
#
#    existence expectancy at birth  Gross income per capita  Income Index  \
# 0                      63.125200             27109.234310      0.646039
# 1                      81.004994             30166.793958      0.852246
# 2                      59.570534              8441.707353      0.499762
# 3                      52.333293                      NaN           NaN
# 4                      81.802464             81033.956906      1.131163
#
# ...

# %%
test = pd.read_csv('../../data/test.csv')  
m, n = test.shape                
print('Data Frame: {} x {}'.format(m,n))                
test.head()
# Out:
# Data Frame: 890 x 79
#    galactic year         galaxy  existence expectancy index  existence expectancy at birth  \
# 0        1007012        KK98 77                    0.456086                      51.562543
# 1        1007012  Reticulum III                    0.529835                      57.228262
# 2        1008016  Reticulum III                    0.560976                      59.379539
# 3        1007012        Segue 1                    0.565910                      59.952390
# 4        1013042        Virgo I                    0.588274                      55.428320
#
#    Gross income per capita  Income Index  Expected years of education (galactic years)  \
# 0             12236.576447      0.593325                                     10.414164
# 1              3431.883825      0.675407                                      7.239485
# 2             27562.914252      0.594624                                     11.774890
# ...

# %%
df = train.append(test, ignore_index=True)
df
# Out:
#       galactic year                        galaxy  existence expectancy index  \
# 0            990025  Large Magellanic Cloud (LMC)                    0.628657
# 1            990025              Camelopardalis B                    0.818082
# 2            990025                       Virgo I                    0.659443
# 3            990025            UGC 8651 (DDO 181)                    0.555862
# 4            990025                  Tucana Dwarf                    0.991196
# ...             ...                           ...                         ...
# 4750        1016064          ESO 383-087 (ISG 39)                         NaN
# 4751        1016064                       NGC 247                         NaN
# 4752        1016064                    ESO 325-11                         NaN
# 4753        1016064                   ESO 540-032                         NaN
# 4754        1016064                       KK98 77                         NaN
#
# ...

# %%
keyword = 'GGP'

# %%
# remove 'Gross galactic product (GGP) per capita'
ggp = df.loc[:, df.columns.str.contains(keyword)].drop('Gross galactic product (GGP) per capita', axis=1)
ggp
# Out:
#       Gross capital formation (% of GGP)  Gross galactic product (GGP), total  \
# 0                              38.305483                          7760.639489
# 1                              36.255559                          6969.137436
# 2                              18.093991                          3276.634176
# 3                                    NaN                                  NaN
# 4                              34.497468                          8957.403969
# ...                                  ...                                  ...
# 4750                                 NaN                                  NaN
# 4751                                 NaN                                  NaN
# 4752                                 NaN                                  NaN
# 4753                                 NaN                                  NaN
# 4754                                 NaN                                  NaN
#
# ...

# %%
y = 'Gross galactic product (GGP), total'
X = ggp.columns.drop(y)
cols = ggp.columns

# %%
ggp.notna().sum()
# Out:
# Gross capital formation (% of GGP)                          2330
# Gross galactic product (GGP), total                         1807
# Outer Galaxies direct investment, net inflows (% of GGP)    1779
# Exports and imports (% of GGP)                              1733
# Domestic credit provided by financial sector (% of GGP)     1648
# Gross fixed capital formation (% of GGP)                    1630
# Remittances, inflows (% of GGP)                             1604
# Current health expenditure (% of GGP)                       1473
# Private galaxy capital flows (% of GGP)                     1410
# dtype: int64

# %%
X_ggp = ggp[X].to_numpy()
y_ggp = ggp[y].to_numpy()

# %%
y_ggp = y_ggp.reshape(y_ggp.shape[0], 1)

# %%
ggp
# Out:
#       Gross capital formation (% of GGP)  Gross galactic product (GGP), total  \
# 0                              38.305483                          7760.639489
# 1                              36.255559                          6969.137436
# 2                              18.093991                          3276.634176
# 3                                    NaN                                  NaN
# 4                              34.497468                          8957.403969
# ...                                  ...                                  ...
# 4750                                 NaN                                  NaN
# 4751                                 NaN                                  NaN
# 4752                                 NaN                                  NaN
# 4753                                 NaN                                  NaN
# 4754                                 NaN                                  NaN
#
# ...

# %%
res = np.divide(X_ggp, y_ggp) * 100
res = pd.DataFrame(res, columns=X)
res.mean()
# Out:
# Gross capital formation (% of GGP)                          0.538475
# Outer Galaxies direct investment, net inflows (% of GGP)    0.316518
# Exports and imports (% of GGP)                              2.383632
# Domestic credit provided by financial sector (% of GGP)     2.107906
# Gross fixed capital formation (% of GGP)                    0.502811
# Remittances, inflows (% of GGP)                             0.229608
# Current health expenditure (% of GGP)                       0.151602
# Private galaxy capital flows (% of GGP)                     0.414401
# dtype: float64

# %%
px.histogram(res, X[0], nbins=1000)
# Out:
# <div>
#
#
#             <div id="6e2de2b3-9eb8-4292-9a4f-4829cb9dbc0f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6e2de2b3-9eb8-4292-9a4f-4829cb9dbc0f")) {
#                     Plotly.newPlot(
#                         '6e2de2b3-9eb8-4292-9a4f-4829cb9dbc0f',
# ...
